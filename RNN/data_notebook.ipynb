# %%
from IMPORTS import *

# %%
# Import data
df = pd.read_csv('../data/part_data_with_vixy.csv')

# %% [markdown]
# ## Columns

# %%
df.columns
# Out:
# Index(['Date', 'SPY', 'SPY_Volume', 'VOO', 'VOO_Volume', 'IVV', 'IVV_Volume',
#        'QQQ', 'QQQ_Volume', 'DIA', 'DIA_Volume', 'TLT', 'TLT_Volume', 'GOVT',
#        'GOVT_Volume', 'IEF', 'IEF_Volume', 'SHY', 'SHY_Volume', 'GLD',
#        'GLD_Volume', 'IAU', 'IAU_Volume', 'LQD', 'LQD_Volume', 'VCIT',
#        'VCIT_Volume', 'VCSH', 'VCSH_Volume', 'IGSB', 'IGSB_Volume', 'AMZN',
#        'AMZN_Volume', 'AAPL', 'AAPL_Volume', 'MSFT', 'MSFT_Volume', 'FB',
#        'FB_Volume', 'GOOG', 'GOOG_Volume', 'GOOGL', 'GOOGL_Volume', 'NFLX',
#        'NFLX_Volume', 'TSLA', 'TSLA_Volume', 'VIXY', 'VIXY_Volume'],
#       dtype='object')

# %% [markdown]
# ## Graph of SPY

# %%
px.line(df, x='Date', y='SPY', template="plotly_dark")
# Out:
# <div>                            <div id="7463878a-f50b-4d1b-a297-64b2fe1cc9df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7463878a-f50b-4d1b-a297-64b2fe1cc9df")) {                    Plotly.newPlot(                        "7463878a-f50b-4d1b-a297-64b2fe1cc9df",                        [{"hovertemplate": "Date=%{x}<br>SPY=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["26/10/2020 16:30", "26/10/2020 16:31", "26/10/2020 16:32", "26/10/2020 16:33", "26/10/2020 16:34", "26/10/2020 16:35", "26/10/2020 16:36", "26/10/2020 16:37", "26/10/2020 16:38", "26/10/2020 16:39", "26/10/2020 16:40", "26/10/2020 16:41", "26/10/2020 16:42", "26/10
# ...

# %%
df.info()
# Out:
# (28680, 49)
